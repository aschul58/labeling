# %% [markdown]
# # Imports

# %%
import pandas as pd
import statistics
#%run config.ipynb
import import_ipynb
from config import *
from data_preparation import *
from data_exploration import *
from labeling import *
from model_training import *
from label_exploration import *
from model_evaluation import *
# Out:
# importing Jupyter notebook from config.ipynb
# importing Jupyter notebook from data_preparation.ipynb
# importing Jupyter notebook from data_exploration.ipynb
# importing Jupyter notebook from labeling.ipynb
# importing Jupyter notebook from model_training.ipynb
# importing Jupyter notebook from label_exploration.ipynb
# importing Jupyter notebook from model_evaluation.ipynb

# %% [markdown]
# # Data preparation

# %%
#Dictionary as data structure with coin name as key which stores the according dataframe 
daily_crypto_dict = {}
weekly_crypto_dict = {}

# %%
#reading the csv files of crypto currencies for daily and weekly directories
daily_dict = read_dir_of_csv(daily_crypto_dict, directory_daily)
weekly_dict = read_dir_of_csv(weekly_crypto_dict, directory_weekly)

# %%
#drop rows where no data for prices available (crypto currency is too young)
daily_dict = clean_dfs_prices(daily_dict)
weekly_dict = clean_dfs_prices(weekly_dict)

# %%
#drop rows where no data for prices available (crypto currency is too young)
daily_dict = convert_timestamps(daily_dict)
weekly_dict = convert_timestamps(weekly_dict)

# %%
#assign time horizon for each data point according to the window that was defined in the config
daily_dict = assign_horizons(daily_dict, delta)
weekly_dict = assign_horizons(weekly_dict, delta)

# %%
#allign data tails according to the configurated time window
daily_dict = allign_all_tails(daily_dict, window_in_days)
weekly_dict = allign_all_tails(weekly_dict, window_in_days)

# %% [markdown]
# # Labeling

# %%
# Label the currencies according to the triple barrier method
daily_dict = apply_tbm(daily_dict, volatility_delta)
weekly_dict = apply_tbm(weekly_dict, volatility_delta)

# %%
# Label the currencies according to the fixed horizon method
daily_dict = apply_fixed_time_horizon(daily_dict, threshold)
weekly_dict = apply_fixed_time_horizon(weekly_dict, threshold)

# %%
#Assign relative returns within the given horizon
daily_dict = assign_relative_returns(daily_dict)
weekly_dict = assign_relative_returns(weekly_dict)

# %%
# Calculating and storing the market means and median on a daily and weekly base each
daily_mean_returns, daily_median_returns = calculate_mean_median_market_return(daily_dict)
weekly_mean_returns, weekly_median_returns = calculate_mean_median_market_return(weekly_dict)

# %%
#Assign relative returns within the given horizon
daily_dict = assign_excess_over_mean_median_label(daily_dict, daily_mean_returns, daily_median_returns)
weekly_dict = assign_excess_over_mean_median_label(weekly_dict, weekly_mean_returns, weekly_median_returns)

# %%
# Train lgbm classifier based on the previously assigned labels
trained_currencies_daily = apply_training(daily_dict)
trained_currencies_weekly = apply_training(weekly_dict)

# %%
# explore how labels are distributed
check_label_distribution(daily_dict)
check_label_distribution(weekly_dict)
# Out:
# Chainlink
# excess over mean
# excess_over_mean
# -1.0    1160
#  1.0    1038
#  0.0       1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    1022
#  1.0    1005
#  0.0     172
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  1.0    1048
# -1.0     846
#  0.0     305
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# 1     1184
# -1    1004
# 0       11
# Name: count, dtype: int64
# ------------------------------
# Poylgon
# excess over mean
# excess_over_mean
# -1.0    931
#  1.0    741
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    895
#  1.0    777
#  0.0      1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  1.0    720
# -1.0    566
#  0.0    387
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# 1     884
# -1    781
# 0       8
# Name: count, dtype: int64
# ------------------------------
# Curve
# excess over mean
# excess_over_mean
# -1.0    726
#  1.0    481
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    729
#  1.0    478
#  0.0      1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  1.0    528
# -1.0    504
#  0.0    176
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    624
# 1     579
# 0       5
# Name: count, dtype: int64
# ------------------------------
# Ribbon
# excess over mean
# excess_over_mean
# -1.0    469
#  1.0    319
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    447
#  1.0    341
#  0.0      1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
# -1.0    331
#  1.0    298
#  0.0    160
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    423
# 1     357
# 0       9
# Name: count, dtype: int64
# ------------------------------
# Uniswap
# excess over mean
# excess_over_mean
# -1.0    707
#  1.0    466
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    696
#  1.0    477
#  0.0      1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  1.0    497
# -1.0    493
#  0.0    184
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    603
# 1     561
# 0      10
# Name: count, dtype: int64
# ------------------------------
# Dydx
# excess over mean
# excess_over_mean
# -1.0    510
#  1.0    307
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    494
#  1.0    323
#  0.0      1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
# -1.0    351
#  1.0    325
#  0.0    142
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    457
# 1     358
# 0       3
# Name: count, dtype: int64
# ------------------------------
# Aave
# excess over mean
# excess_over_mean
# -1.0    688
#  1.0    471
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    672
#  1.0    487
#  0.0      1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    570
#  1.0    298
# -1.0    292
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# 1     592
# -1    566
# 0       2
# Name: count, dtype: int64
# ------------------------------
# Lido
# excess over mean
# excess_over_mean
# -1.0    610
#  1.0    437
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    602
#  1.0    445
#  0.0      1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  1.0    422
# -1.0    398
#  0.0    228
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    569
# 1     473
# 0       6
# Name: count, dtype: int64
# ------------------------------
# Ethereum
# excess over mean
# excess_over_mean
#  1.0    1103
# -1.0    1095
#  0.0       1
# Name: count, dtype: int64
# excess over median
# excess_over_median
#  1.0    1002
# -1.0     852
#  0.0     345
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  1.0    1033
# -1.0     844
#  0.0     322
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# 1     1182
# -1    1002
# 0       15
# Name: count, dtype: int64
# ------------------------------
# Bitcoin
# excess over mean
# excess_over_mean
# -1.0    1156
#  1.0    1042
#  0.0       1
# Name: count, dtype: int64
# excess over median
# excess_over_median
#  1.0    996
# -1.0    870
#  0.0    333
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  1.0    971
# -1.0    800
#  0.0    428
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# 1     1161
# -1    1015
# 0       23
# Name: count, dtype: int64
# ------------------------------
# SHIB
# excess over mean
# excess_over_mean
# -1.0    611
#  1.0    330
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    609
#  1.0    332
#  0.0      1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
# -1.0    339
#  1.0    318
#  0.0    285
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    528
# 1     408
# 0       6
# Name: count, dtype: int64
# ------------------------------
# Pepe
# excess over mean
# excess_over_mean
# -1.0    155
#  1.0     59
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    146
#  1.0     68
#  0.0      1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
# -1.0    95
#  1.0    81
#  0.0    39
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    132
# 1      82
# 0       1
# Name: count, dtype: int64
# ------------------------------
# Chainlink
# excess over mean
# excess_over_mean
# -1.0    162
#  1.0    150
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
#  1.0    144
# -1.0    140
#  0.0     29
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    196
#  1.0     75
# -1.0     42
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# 1     172
# -1    139
# 0       2
# Name: count, dtype: int64
# ------------------------------
# Curve
# excess over mean
# excess_over_mean
# -1.0    106
#  1.0     64
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    104
#  1.0     66
#  0.0      1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    106
#  1.0     34
# -1.0     31
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    86
# 1     84
# 0      1
# Name: count, dtype: int64
# ------------------------------
# Ribbon
# excess over mean
# excess_over_mean
# -1.0    64
#  1.0    46
#  0.0     1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    61
#  1.0    49
#  0.0     1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    68
# -1.0    22
#  1.0    21
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    59
# 1     50
# 0      2
# Name: count, dtype: int64
# ------------------------------
# Uniswap
# excess over mean
# excess_over_mean
# -1.0    95
#  1.0    70
#  0.0     1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    95
#  1.0    70
#  0.0     1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    107
#  1.0     32
# -1.0     27
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    83
# 1     81
# 0      2
# Name: count, dtype: int64
# ------------------------------
# Dydx
# excess over mean
# excess_over_mean
# -1.0    74
#  1.0    40
#  0.0     1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    72
#  1.0    42
#  0.0     1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    74
# -1.0    21
#  1.0    20
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    70
# 1     44
# 0      1
# Name: count, dtype: int64
# ------------------------------
# Aave
# excess over mean
# excess_over_mean
# -1.0    101
#  1.0     62
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    98
#  1.0    65
#  0.0     1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
# 0.0    164
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    84
# 1     79
# 0      1
# Name: count, dtype: int64
# ------------------------------
# Lido
# excess over mean
# excess_over_mean
# -1.0    88
#  1.0    59
#  0.0     1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    87
#  1.0    60
#  0.0     1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    110
#  1.0     29
# -1.0      9
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    83
# 1     64
# 0      1
# Name: count, dtype: int64
# ------------------------------
# Polygon
# excess over mean
# excess_over_mean
# -1.0    134
#  1.0    103
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    128
#  1.0    109
#  0.0      1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    183
#  1.0     40
# -1.0     15
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# 1     124
# -1    113
# 0       1
# Name: count, dtype: int64
# ------------------------------
# Ethereum
# excess over mean
# excess_over_mean
# -1.0    157
#  1.0    155
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
#  1.0    150
# -1.0    120
#  0.0     43
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    176
#  1.0     84
# -1.0     53
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# 1     165
# -1    146
# 0       2
# Name: count, dtype: int64
# ------------------------------
# Bitcoin
# excess over mean
# excess_over_mean
# -1.0    171
#  1.0    141
#  0.0      1
# Name: count, dtype: int64
# excess over median
# excess_over_median
#  1.0    146
# -1.0    126
#  0.0     41
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    189
#  1.0     69
# -1.0     55
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# 1     162
# -1    144
# 0       7
# Name: count, dtype: int64
# ------------------------------
# SHIB
# excess over mean
# excess_over_mean
# -1.0    91
#  1.0    41
#  0.0     1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    85
#  1.0    47
#  0.0     1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    121
#  1.0     10
# -1.0      2
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    78
# 1     54
# 0      1
# Name: count, dtype: int64
# ------------------------------
# Pepe
# excess over mean
# excess_over_mean
# -1.0    18
#  1.0    10
#  0.0     1
# Name: count, dtype: int64
# excess over median
# excess_over_median
# -1.0    17
#  1.0    11
#  0.0     1
# Name: count, dtype: int64
# triple Barrier
# tbm_label
#  0.0    16
# -1.0     7
#  1.0     6
# Name: count, dtype: int64
# fixed time horizon
# fth_label
# -1    17
# 1     11
# 0      1
# Name: count, dtype: int64
# ------------------------------

# %%
# Evaluate accuracies
print("Daily data")
evaluate_accuracy(trained_currencies_daily)
print("Weekly data")
evaluate_accuracy(trained_currencies_weekly)
# Out:
# Chainlink
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.4463
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.4189
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.5537
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.4845
# ------------------------------
# Poylgon
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.4761
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.5096
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.5742
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.4163
# ------------------------------
# Curve
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.5000
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.4868
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.4570
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.3974
# ------------------------------
# Ribbon
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.5025
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.4518
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.5736
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.2741
# ------------------------------
# Uniswap
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.4608
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.5119
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.5051
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.4369
# ------------------------------
# Dydx
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.5539
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.5343
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.5735
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.3824
# ------------------------------
# Aave
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.5448
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.4793
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.4483
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.3966
# ------------------------------
# Lido
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.5229
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.5458
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.4847
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.3931
# ------------------------------
# Ethereum
# excess_over_mean
# Training set score: 0.9988
# Test set score: 0.5009
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.2951
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.4390
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.4080
# ------------------------------
# Bitcoin
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.5410
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.3133
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.5683
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.4117
# ------------------------------
# SHIB
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.4170
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.5574
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.4468
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.4043
# ------------------------------
# Pepe
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.6415
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.6038
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.4340
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.3396
# ------------------------------
# Chainlink
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.4359
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.3462
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.5385
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.5641
# ------------------------------
# Curve
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.3333
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.3810
# fixed_time_horizon
# Training set score: 0.9845
# Test set score: 0.4286
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.5476
# ------------------------------
# Ribbon
# excess_over_mean
# Training set score: 0.9524
# Test set score: 0.5556
# excess_over_median
# Training set score: 0.9405
# Test set score: 0.5556
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.6296
# triple_barrier
# Training set score: 0.9881
# Test set score: 0.8148
# ------------------------------
# Uniswap
# excess_over_mean
# Training set score: 0.9920
# Test set score: 0.5366
# excess_over_median
# Training set score: 0.9840
# Test set score: 0.6341
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.4146
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.5610
# ------------------------------
# Dydx
# excess_over_mean
# Training set score: 0.9770
# Test set score: 0.4643
# excess_over_median
# Training set score: 0.9770
# Test set score: 0.4643
# fixed_time_horizon
# Training set score: 0.9885
# Test set score: 0.5000
# triple_barrier
# Training set score: 0.9885
# Test set score: 0.7143
# ------------------------------
# Aave
# excess_over_mean
# Training set score: 0.9756
# Test set score: 0.6341
# excess_over_median
# Training set score: 0.9837
# Test set score: 0.7073
# fixed_time_horizon
# Training set score: 0.9837
# Test set score: 0.5854
# triple_barrier
# Training set score: 1.0000
# Test set score: 1.0000
# ------------------------------
# Lido
# excess_over_mean
# Training set score: 0.9820
# Test set score: 0.7568
# excess_over_median
# Training set score: 0.9640
# Test set score: 0.6216
# fixed_time_horizon
# Training set score: 0.9910
# Test set score: 0.3784
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.7568
# ------------------------------
# Polygon
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.5424
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.6441
# fixed_time_horizon
# Training set score: 0.9944
# Test set score: 0.5593
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.5085
# ------------------------------
# Ethereum
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.5385
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.3590
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.4872
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.5128
# ------------------------------
# Bitcoin
# excess_over_mean
# Training set score: 1.0000
# Test set score: 0.5000
# excess_over_median
# Training set score: 1.0000
# Test set score: 0.2949
# fixed_time_horizon
# Training set score: 1.0000
# Test set score: 0.5128
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.6026
# ------------------------------
# SHIB
# excess_over_mean
# Training set score: 0.9800
# Test set score: 0.3939
# excess_over_median
# Training set score: 0.9700
# Test set score: 0.3333
# fixed_time_horizon
# Training set score: 0.9700
# Test set score: 0.2424
# triple_barrier
# Training set score: 1.0000
# Test set score: 0.9697
# ------------------------------
# Pepe
# excess_over_mean
# Training set score: 0.6364
# Test set score: 0.5714
# excess_over_median
# Training set score: 0.5909
# Test set score: 0.5714
# fixed_time_horizon
# Training set score: 0.6364
# Test set score: 0.4286
# triple_barrier
# Training set score: 0.5000
# Test set score: 0.7143
# ------------------------------
